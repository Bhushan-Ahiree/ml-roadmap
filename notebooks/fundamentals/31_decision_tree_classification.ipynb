# %% [markdown]
# # Decision Tree Classification
#
# A Decision Tree learns decision rules from training data and uses those rules to predict the class of new observations.
#
# Unlike KNN, it does not make predictions by measuring distances.
#
# Unlike Logistic Regression, it can naturally model non-linear relationships.

# %% [markdown]
# # Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Explain how a Decision Tree works.
# - Understand nodes, branches, and leaves.
# - Train a Decision Tree classifier.
# - Understand why scaling is unnecessary.
# - Understand how tree depth affects overfitting.
# - Evaluate a Decision Tree classifier.

# %%
from sklearn.datasets import load_iris
import pandas as pd

data = load_iris(as_frame=True)

df = data.frame

df.head()
