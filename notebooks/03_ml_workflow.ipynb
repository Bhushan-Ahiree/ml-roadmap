# %% [markdown]
# ## Step 1 — Business Problem
#
# Every ML project starts with a business problem.
#
# Example:
# Predict the selling price of a property before it is listed.

# %% [markdown]
# ## Step 2 — Collect Data
#
# Example Dataset
#
# | Area | Bedrooms | Age | Price |
# |------|----------|-----|-------|
# |1200|2|5|75L|
# |1500|3|2|95L|

# %%
properties = [
    {"Area": 1200, "Bedrooms": 2, "Age": 5, "Price": 75},
    {"Area": 1500, "Bedrooms": 3, "Age": 2, "Price": 95},
    {"Area": 900, "Bedrooms": 2, "Age": 10, "Price": 52}
]

for property in properties:
    print(property)
# Out:
# {'Area': 1200, 'Bedrooms': 2, 'Age': 5, 'Price': 75}
# {'Area': 1500, 'Bedrooms': 3, 'Age': 2, 'Price': 95}
# {'Area': 900, 'Bedrooms': 2, 'Age': 10, 'Price': 52}

# %% [markdown]
# ## Understand Data
#
# Before training any model, understand:
#
# - Number of rows
# - Number of columns
# - Data types
# - Missing values
# - Target variable

# %% [markdown]
# ## Clean Data
#
# Typical tasks
#
# - Remove duplicates
# - Handle missing values
# - Fix data types
# - Handle outliers

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Ask questions such as:
#
# - What is the average price?
# - Which feature affects price most?
# - Are there outliers?
# - How are features related?

# %% [markdown]
# ## Next Steps
#
# - Feature Engineering
# - Train/Test Split
# - Model Training
# - Model Evaluation
# - Deployment

# %% [markdown]
# ## Key Takeaways
#
# Machine Learning is much more than training a model.
#
# Most time is spent understanding, cleaning, and preparing data before model training.
