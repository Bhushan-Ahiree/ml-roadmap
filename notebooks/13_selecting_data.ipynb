# %%
import pandas as pd

# %%
student = {
    "Name":["Bhushan","Rahul","Sneha","Amit"],
    "Age":[22,21,23,24],
    "City":["Pune","Mumbai","Nashik","Delhi"],
    "Marks":[82,90,88,75]
}

df = pd.DataFrame(student)

df

# %%
df["Name"]
