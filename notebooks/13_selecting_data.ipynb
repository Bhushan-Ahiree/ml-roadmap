# %%
import pandas as pd

# %%
student = {
    "Name":["Bhushan","Rahul","Sneha","Amit"],
    "Age":[22,21,23,24],
    "City":["Pune","Mumbai","Nashik","Delhi"],
    "Marks":[82,90,88,75]
}

df = pd.DataFrame(student)

df
# Out:
#       Name  Age    City  Marks
# 0  Bhushan   22    Pune     82
# 1    Rahul   21  Mumbai     90
# 2    Sneha   23  Nashik     88
# 3     Amit   24   Delhi     75

# %%
df["Name"]
# Out:
# 0    Bhushan
# 1      Rahul
# 2      Sneha
# 3       Amit
# Name: Name, dtype: str

# %%
df[["Name"]]
# Out:
#       Name
# 0  Bhushan
# 1    Rahul
# 2    Sneha
# 3     Amit

# %%
df['Age']
# Out:
# 0    22
# 1    21
# 2    23
# 3    24
# Name: Age, dtype: int64

# %%
df[["Name","Marks"]]
# Out:
#       Name  Marks
# 0  Bhushan     82
# 1    Rahul     90
# 2    Sneha     88
# 3     Amit     75

# %%
df.loc[0]
# Out:
# Name     Bhushan
# Age           22
# City        Pune
# Marks         82
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Name     Bhushan
# Age           22
# City        Pune
# Marks         82
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#       Name  Age    City  Marks
# 0  Bhushan   22    Pune     82
# 1    Rahul   21  Mumbai     90
# 2    Sneha   23  Nashik     88

# %%
type(df["Age"])
# Out:
# pandas.Series

# %%
type(df[["Age"]])
# Out:
# pandas.DataFrame
