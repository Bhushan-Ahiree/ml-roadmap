# %% [markdown]
# # NumPy Shapes & Dimensions
#
# ## Objective
#
# Understand dimensions, shapes and metadata of NumPy arrays.

# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40, 50])

arr
# Out:
# array([10, 20, 30, 40, 50])

# %%
print("Dimension :", arr.ndim)

print("Shape :", arr.shape)

print("Size :", arr.size)

print("Data Type :", arr.dtype)
# Out:
# Dimension : 1
# Shape : (5,)
# Size : 5
# Data Type : int64

# %%
matrix = np.array([
    [1,2,3],
    [4,5,6]
])

matrix
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
print("Dimension :", matrix.ndim)

print("Shape :", matrix.shape)

print("Size :", matrix.size)

print("Data Type :", matrix.dtype)
# Out:
# Dimension : 2
# Shape : (2, 3)
# Size : 6
# Data Type : int64

# %%
cube = np.array([
    [
        [1,2],
        [3,4]
    ],
    [
        [5,6],
        [7,8]
    ]
])

cube
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
print("Dimension :", cube.ndim)

print("Shape :", cube.shape)

print("Size :", cube.size)

print("Data Type :", cube.dtype)
# Out:
# Dimension : 3
# Shape : (2, 2, 2)
# Size : 8
# Data Type : int64

# %%
print(type(cube))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Observation
#
# - ndim → number of dimensions
# - shape → size of each dimension
# - size → total number of elements
# - dtype → data type
