# %% [markdown]
# # NumPy Fundamentals
#
# ## Objective
#
# Learn why NumPy exists and create your first NumPy arrays.

# %%
import numpy as np

numbers = np.array([10,20,30,40,50])
numbers
# Out:
# array([10, 20, 30, 40, 50])

# %%
type(numbers)
# Out:
# numpy.ndarray

# %%
np.ndarray
# Out:
# numpy.ndarray

# %%
print(numbers)
# Out:
# [10 20 30 40 50]

# %%
print(numbers[0])
# Out:
# 10

# %%
print(numbers[3])
# Out:
# 40

# %%
print(numbers[-1])
# Out:
# 50
