# %% [markdown]
# # NumPy Indexing & Slicing
#
# ## Objective
#
# Learn how to access data from NumPy arrays.

# %%
import numpy as np

# %%
arr = np.array([10,20,30,40,50])

arr
# Out:
# array([10, 20, 30, 40, 50])

# %%
print(arr[0])

print(arr[2])

print(arr[-1])
# Out:
# 10
# 30
# 50

# %%
print(arr[1:4])
# Out:
# [20 30 40]

# %%
print(arr[:3])

print(arr[2:])

print(arr[:])
# Out:
# [10 20 30]
# [30 40 50]
# [10 20 30 40 50]

# %%
print(arr[::2])
# Out:
# [10 30 50]

# %%
matrix = np.array([
    [10,20,30],
    [40,50,60],
    [70,80,90]
])

matrix
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
print(matrix[0,1])

print(matrix[2,2])
# Out:
# 20
# 90

# %%
print(matrix[:,1])
# Out:
# [20 50 80]

# %%
print(matrix[1,:])
# Out:
# [40 50 60]

# %%
print(matrix[0:2,1:3])
# Out:
# [[20 30]
#  [50 60]]

# %% [markdown]
# Create
#
#     [85,90,88]
#     [78,81,79]
#     [92,95,94]
#
#
# Print
#
# 1. First row
# 2. Second column
# 3. Last row
# 4. First two rows
# 5. Last two columns

# %%
scores = np.array([ 
                [85,90,88],
                [78,81,79],
                [92,95,94]])

scores
# Out:
# array([[85, 90, 88],
#        [78, 81, 79],
#        [92, 95, 94]])

# %%
print(scores[0,:])
# Out:
# [85 90 88]

# %%
print(scores[:,1])
# Out:
# [90 81 95]

# %%
print(scores[-1,:])
# Out:
# [92 95 94]

# %%
print(scores[:2,:])
# Out:
# [[85 90 88]
#  [78 81 79]]

# %%
print(scores[:,1:3])
# Out:
# [[90 88]
#  [81 79]
#  [95 94]]
